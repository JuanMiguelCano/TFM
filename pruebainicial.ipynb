# %%
# PREPARACIÓN DE LOS DATOS 02/05/2023
import pandas as pd
import numpy as np

df = pd.read_excel('data_original.xlsx', engine='openpyxl')

# Se elimina la columna Id
df.drop('Id', axis=1, inplace=True)

# Se discretiza la columna Edad usando los terciles
terciles = df['Edad'].quantile([0.33, 0.66])
df['Edad'] = pd.cut(df['Edad'], 
                                 bins=[df['Edad'].min()-1, terciles[0.33], terciles[0.66], df['Edad'].max()], 
                                 labels=[0, 1, 2])

# Se completan los valores faltantes de Peso con los valores de Peso.PSS
df['Peso'].fillna(df['Peso.PSS'], inplace=True)
df.drop('Peso.PSS', axis=1, inplace=True) # Se elimina la columna Peso.PSS

# Se completan los valores faltantes de Talla con los valores de Talla.PSS
df['Talla'].fillna(df['Talla.PSS'], inplace=True)
df.drop('Talla.PSS', axis=1, inplace=True) # Se elimina la columna Talla.PSS

# Se categorizan las variables Peso y Talla (altura), para ello se usa el IMC
df['Peso'] = df['Peso'] / (df['Talla']/100)**2
bins = [0, 18.5, 25, 30, np.inf]
labels = [1, 2, 3, 4]
df.rename(columns={'Peso': 'IMC'}, inplace=True)
df['IMC'] = pd.cut(df['IMC'], bins=bins, labels=labels)
df.drop('Talla', axis=1, inplace=True) # Se elimina la columna Talla
df['TratamientoDM'].fillna(-1, inplace=True)
df.drop('Filtrado Glomerular', axis=1, inplace=True) # CONTINUA & DEMASIADOS VALORES FALTANTES
df.drop('HBpreKT', axis=1, inplace=True) # CONTINUA
df['LocIAMprevio'].fillna(-1, inplace=True)
df.drop('QXcoronariapre', axis=1, inplace=True) # POCOS VALORES DISTINTOS DE 1
df.drop('AnoQXcoronariapre', axis=1, inplace=True) # FECHA
df.drop('PuentesQxpre.Tx', axis=1, inplace=True) # DEMASIADOS VALORES FALTANTES
# df.drop('ACTPprevia', axis=1, inplace=True)
df.drop('AnoACTPprevia', axis=1, inplace=True) # FECHA
df.drop('TCI.stentpre', axis=1, inplace=True) # DEMASIADOS 0
df.drop('DA.stentpre', axis=1, inplace=True) # DEMASIADOS VALORES FALTANTES POCOS 1
df.drop('Cx.stentpre', axis=1, inplace=True) #.
df.drop('MOB.stentpre', axis=1, inplace=True) #.
df.drop('CD.stentpre', axis=1, inplace=True) #.
df.drop('PL.stentpre', axis=1, inplace=True) #.
df.drop('IVP.stentpre', axis=1, inplace=True) #.
# df.drop('EnfArtPerif.pre', axis=1, inplace=True) 
df.drop('CHADS2', axis=1, inplace=True) # SIN NINGÚN VALOR
df.drop('Grace', axis=1, inplace=True) # CONTINUA
df.drop('PreciseDAPT', axis=1, inplace=True) # CONTINUA
df.drop('Unnamed: 34', axis=1, inplace=True) # FECHA
df.drop('FE', axis=1, inplace=True) # CONTINUA
df.drop('IndicacionIAMCEST', axis=1, inplace=True) # DEMASIADOS VALORES FALTANTES
df.drop('TCI.Actual', axis=1, inplace=True) #.
df.drop('DA.Actual', axis=1, inplace=True) #.
df.drop('CX.Actual', axis=1, inplace=True) #.
df.drop('CD.Actual', axis=1, inplace=True) #.
df.drop('Mamaria.Actual', axis=1, inplace=True) #.
df.drop('Safena.Actual', axis=1, inplace=True) #.
df.drop('FechaQx.Actual', axis=1, inplace=True) # FECHA
df.drop('Puentes.Actual', axis=1, inplace=True) # DEMASIADOS VALORES FALTANTES & PUENTES ESPECIFICOS
df.drop('ACVQX.Actual', axis=1, inplace=True) # DEMASIADOS VALORES FALTANTES
df.drop('InfartoQX.Actual', axis=1, inplace=True) # DEMASIADOS VALORES FALTANTES
df.drop('MuerteQX.Actual', axis=1, inplace=True) # DEMASIADOS VALORES FALTANTES
df.drop('MuerteQXtexto', axis=1, inplace=True) # SIN NINGÚN VALOR
df.drop('TCI.tratada', axis=1, inplace=True) #.
df.drop('DA.tratada', axis=1, inplace=True) #.
df.drop('Cx.tratada', axis=1, inplace=True) #.
df.drop('CD.tratada', axis=1, inplace=True) #.
df.drop('Mamaria.tratada', axis=1, inplace=True) #.
df.drop('Safena.tratada', axis=1, inplace=True) #.
df.drop('SINTAX1', axis=1, inplace=True) # SIN NINGÚN VALOR
df.drop('SINTAX2', axis=1, inplace=True) # SIN NINGÚN VALOR
df.drop('CreaPost', axis=1, inplace=True) # CONTINUA
df.drop('HBpost', axis=1, inplace=True) # CONTINUA Y ALGÚN VALOR FALTANTE
df.drop('FechaMuerteAlta', axis=1, inplace=True) # FECHA Y CASI TODOS VALORES FALTANTES
df.drop('CausaMuerteAlta', axis=1, inplace=True) # CASI TODOS VALORES FALTANTES
df.drop('Shock.Comp', axis=1, inplace=True) # CASI TODOS 0
df.drop('TromboStent.Comp', axis=1, inplace=True) # CASI TODOS 0
df.drop('IAMxOtraLesión.Comp', axis=1, inplace=True) # CASI TODOS 0
df.drop('reACTPmismo.Comp', axis=1, inplace=True) # CASI TODOS 0
df.drop('reACTPnueva.Comp', axis=1, inplace=True) # CASI TODOS 0
df.drop('CirugiaCoro.Comp', axis=1, inplace=True) # CASI TODOS 0
df.drop('Hemorragia.Comp', axis=1, inplace=True) # CASI TODOS 0
df.drop('Infeccion.Comp', axis=1, inplace=True) # CASI TODOS 0
df.drop('AccesoVasc.Comp', axis=1, inplace=True) # CASI TODOS 0
df.drop('Otras.Comp', axis=1, inplace=True) # MUCHOS VALORES FALTANTES
df.drop('DuracionInhADP', axis=1, inplace=True) # MUCHOS VALORES FALTANTES
df.drop('ACO', axis=1, inplace=True) # MUCHOS VALORES FALTANTES
df.drop('DuracionACO', axis=1, inplace=True) # MUCHOS VALORES FALTANTES
df.drop('SegTelef12m', axis=1, inplace=True)
df.drop('NosegTx', axis=1, inplace=True)
df.drop('FechaContacto', axis=1, inplace=True) # FECHA
df.drop('EstadoAnginoso', axis=1, inplace=True) # CON MUY POCOS VALORES AL FINAL
df.drop('ClaseCCS', axis=1, inplace=True) # CON MUY POCOS VALORES AL FINAL
df.drop('InhibADP12m', axis=1, inplace=True) # MUCHOS VALORES FALTANTES
df.drop('ACO12m', axis=1, inplace=True) # MUCHOS VALORES FALTANTES
df.drop('DAPT.Score', axis=1, inplace=True) # SIN NINGÚN VALOR
df.drop('FechaKT.PSS', axis=1, inplace=True) # FECHA
df.drop('DxInicialTx.PSS', axis=1, inplace=True) # TOMA POCOS VALORES TEXT
df.drop('TratDM.PSS', axis=1, inplace=True) # MUCHOS VALORES FALTANTES
df.drop('OtroAntecedTx.PSS', axis=1, inplace=True) # MUCHOS VALORES FALTANTES
df.drop('ConoceEnf.PSS', axis=1, inplace=True)
df.drop('ConociaFRCV.PSS', axis=1, inplace=True)
df.drop('CualesConocia.PSS', axis=1, inplace=True)
df.drop('SabiaTabaco.PSS', axis=1, inplace=True)
df.drop('PensoCorazon.PSS', axis=1, inplace=True)
df.drop('QuePenso.PSS', axis=1, inplace=True)
df.drop('PersonaContac.PSS', axis=1, inplace=True)
df.drop('DondeEstaba.PSS', axis=1, inplace=True)
df.drop('ServSanitContac.PSS', axis=1, inplace=True)
df.drop('TrasladoSS.PSS', axis=1, inplace=True)
df.drop('FechaDolor.PSS', axis=1, inplace=True)
df.drop('HoraDolor.PSS', axis=1, inplace=True)
df.drop('MinutoDolor.PSS', axis=1, inplace=True)
df.drop('FechaSanitario.PSS', axis=1, inplace=True)
df.drop('HoraSanitario.PSS', axis=1, inplace=True)
df.drop('MinutoSanitario.PSS', axis=1, inplace=True)
df.drop('FechaUrgencias.PSS', axis=1, inplace=True)
df.drop('HoraUrg.PSS', axis=1, inplace=True)
df.drop('MinutoUrg.PSS', axis=1, inplace=True)
df.drop('FechaTrat.PSS', axis=1, inplace=True)
df.drop('MinutoTrat.PSS', axis=1, inplace=True)
df.drop('HoraTrat.PSS', axis=1, inplace=True)
df.drop('FechaDolorNH.PSS', axis=1, inplace=True)
df.drop('HoraDolorNH.PSS', axis=1, inplace=True)
df.drop('MinutoDolorNH.PSS', axis=1, inplace=True)
df.drop('FechaContSanitNH.PSS', axis=1, inplace=True)
df.drop('HoraContSanitNH.PSS', axis=1, inplace=True)
df.drop('MinutoContNH.PSS', axis=1, inplace=True)
df.drop('FechaUrgNH.PSS', axis=1, inplace=True)
df.drop('HoraUrgNH.PSS', axis=1, inplace=True)
df.drop('MinutoUrgNH.PSS', axis=1, inplace=True)
df.drop('FechaTraNH.PSS', axis=1, inplace=True)
df.drop('HoraTratNH.PSS', axis=1, inplace=True)
df.drop('MinutoTratNH.PSS', axis=1, inplace=True)
df.drop('T.Exfumador.PSS', axis=1, inplace=True)
df.drop('T.tabaco.PSS', axis=1, inplace=True)
df.drop('CantTabaco.PSS', axis=1, inplace=True)
df.drop('MotivoStopTabaco.PSS', axis=1, inplace=True)
df.drop('IntencionDejar.PSS', axis=1, inplace=True)
df.drop('PodraDejarlo.PSS', axis=1, inplace=True)
df.drop('FumaFamilia.PSS', axis=1, inplace=True)
df.drop('ParejaFuma.PSS', axis=1, inplace=True)
df.drop('PadreFuma.PSS', axis=1, inplace=True)
df.drop('MadreFuma.PSS', axis=1, inplace=True)
df.drop('HijoFuma.PSS', axis=1, inplace=True)
df.drop('NHijosfuman.PSS', axis=1, inplace=True)
df.drop('NHijosQueTiene.PSS', axis=1, inplace=True)
df.drop('OtrosFuma.PSS', axis=1, inplace=True)
df.drop('Vino.PSS', axis=1, inplace=True)
df.drop('Cerveza', axis=1, inplace=True)
df.drop('Copas.PSS', axis=1, inplace=True)
df.drop('Marihuana.PSS', axis=1, inplace=True)
df.drop('Cocaina.PSS', axis=1, inplace=True)
df.drop('OtrosToxicos.PSS', axis=1, inplace=True)
df.drop('DietaTx.PSS', axis=1, inplace=True)
df.drop('Nadar.PSS', axis=1, inplace=True)
df.drop('Correr.PSS', axis=1, inplace=True)
df.drop('Bici.PSS', axis=1, inplace=True)
df.drop('Gimnasio.PSS', axis=1, inplace=True)
df.drop('OtroEjercicioTx', axis=1, inplace=True)
df.drop('FrecEjercicio.PSS', axis=1, inplace=True)
df.drop('IntensEjercicio.PSS', axis=1, inplace=True)
df.drop('HaraMasEjercicio.PSS', axis=1, inplace=True)
df.drop('CualMasEjercicio.PSS', axis=1, inplace=True)
df.drop('SabeColesterol.PSS', axis=1, inplace=True)
df.drop('SabeColesterol.PSS.1', axis=1, inplace=True)
df.drop('QuienTA.PSS', axis=1, inplace=True)
df.drop('Medidas prevencion HTA', axis=1, inplace=True)
df.drop('PrevHTATx.PSS', axis=1, inplace=True)
df.drop('FrecPeso.PSS', axis=1, inplace=True)
df.drop('FrecMedico.PSS', axis=1, inplace=True)
df.drop('Menopausia.PSS', axis=1, inplace=True)
df.drop('Anticonceptivo.PSS', axis=1, inplace=True)
df.drop('Autopercepcion.PSS', axis=1, inplace=True)
df.drop('OlvidaConsult.PSS', axis=1, inplace=True)
df.drop('SabeTrat.PSS', axis=1, inplace=True)
df.drop('ControlMedicac.PSS', axis=1, inplace=True)
df.drop('FrecOlvidoTrat.PSS', axis=1, inplace=True)
df.drop('SaludTV.PSS', axis=1, inplace=True)
df.drop('FamiliaEnferma.PSS', axis=1, inplace=True)
df.drop('FamiliaresConEnfTx', axis=1, inplace=True)
df.drop('ConsultaKT.PSS', axis=1, inplace=True)
df.drop('FamiliaConsultaKT.PSS', axis=1, inplace=True)
df.drop('InternetConsultaKT.PSS', axis=1, inplace=True)
df.drop('Profesionales.KT.PSS', axis=1, inplace=True)
df.drop('ConsultaEnferm.PSS', axis=1, inplace=True)
df.drop('Profesionales.PSS', axis=1, inplace=True)
df.drop('Internet.PSS', axis=1, inplace=True)
df.drop('OtrosConsultEnf.PSS', axis=1, inplace=True)
df.drop('SabeactuarAngina.PSS', axis=1, inplace=True)
df.drop('ActAnginaTx.PSS', axis=1, inplace=True)
df.drop('TareasHogar.PSS', axis=1, inplace=True)
df.drop('NHijos.PSS', axis=1, inplace=True)
df.drop('NNietos.PSS', axis=1, inplace=True)
df.drop('MascotasTx.PSS', axis=1, inplace=True)
df.drop('Familia.Aficc.PSS', axis=1, inplace=True)
df.drop('TV.Aficc.PSS', axis=1, inplace=True)
df.drop('Amigos.Aficc.PSS', axis=1, inplace=True)
df.drop('Musica.Aficc.PSS', axis=1, inplace=True)
df.drop('Lectura.Aficc.PSS', axis=1, inplace=True)
df.drop('Radio.Aficc.PSS', axis=1, inplace=True)
df.drop('Compras.Aficc.PSS', axis=1, inplace=True)
df.drop('Cine.Aficc.PSS', axis=1, inplace=True)
df.drop('Campo.Aficc.PSS', axis=1, inplace=True)
df.drop('VerDeportes.Aficc.PSS', axis=1, inplace=True)
df.drop('Bailar.Aficc.PSS', axis=1, inplace=True)
df.drop('Cultura.Aficc.PSS', axis=1, inplace=True)
df.drop('SalirComer.Aficc.PSS', axis=1, inplace=True)
df.drop('Pub.Aficc.PSS', axis=1, inplace=True)
df.drop('Otros.Aficc.PSS', axis=1, inplace=True)
df.drop('Autobus.PSS', axis=1, inplace=True)
df.drop('Taxi.PSS', axis=1, inplace=True)
df.drop('Coche.PSS', axis=1, inplace=True)
df.drop('Moto.PSS', axis=1, inplace=True)
df.drop('Bici.PSS.1', axis=1, inplace=True)
df.drop('Caminando.PSS', axis=1, inplace=True)
df.drop('OtrosVehiculos.PSS', axis=1, inplace=True)
df.drop('Facebook.PSS', axis=1, inplace=True)
df.drop('Twitter.PSS', axis=1, inplace=True)
df.drop('Youtube.PSS', axis=1, inplace=True)
df.drop('LinkeDin.PSS', axis=1, inplace=True)
df.drop('Spotify.PSS', axis=1, inplace=True)
df.drop('OtrasRedes.PSS', axis=1, inplace=True)
df.drop('APPs.PSS', axis=1, inplace=True)
df.drop('Internet.PSS.1', axis=1, inplace=True)
df.drop('Tablet.PSS', axis=1, inplace=True)
df.drop('Ordenador.PSS', axis=1, inplace=True)
df.drop('Portatil.PSS', axis=1, inplace=True)
df.drop('SmartTV.PSS', axis=1, inplace=True)
df.drop('Wifi.Publica.PSS', axis=1, inplace=True)
df.drop('ConoceSkype.PSS', axis=1, inplace=True)
df.drop('UsaSkype', axis=1, inplace=True)
df.drop('Fecha entrada', axis=1, inplace=True)
df.drop('FechaEstadoVital', axis=1, inplace=True)
df.drop('CausaMuerte', axis=1, inplace=True)
df.drop('Fecha muerte', axis=1, inplace=True)
df.drop('Fecha muerte CV', axis=1, inplace=True)
df.drop('Fecha IAM', axis=1, inplace=True)
df['N.Infartos.Seg'].fillna(0, inplace=True)
df.drop('IAM2', axis=1, inplace=True)
df.drop('Fecha IAM2', axis=1, inplace=True)
df.drop('IAM3', axis=1, inplace=True)
df.drop('Fecha IAM3', axis=1, inplace=True)
df.drop('Fecha revasc', axis=1, inplace=True)
# Actualizamos Revasc por la suma de Revasc, Revasc2 y Revasc3
df['Revasc'] = df['Revasc'].notna().astype(int) + df['Revasc2'].notna().astype(int) + df['Revasc3'].notna().astype(int)
df.drop('Revasc2', axis=1, inplace=True)
df.drop('Fecha revasc2', axis=1, inplace=True)
df.drop('Revasc3', axis=1, inplace=True)
df.drop('Fecha revasc3', axis=1, inplace=True)
df.drop('Fecha ictus', axis=1, inplace=True)
df.drop('Fecha hemorragia', axis=1, inplace=True)
df.drop('Fecha fin seg', axis=1, inplace=True)

# Eliminamos la filas con valores faltantes
df.dropna(inplace=True)

# Quitamos los espacios/interrogaciones en los nombres de las columnas para evitar problemas en R
df.columns = df.columns.str.replace(' ', '')
df.columns = df.columns.str.replace('¿', '')
df.columns = df.columns.str.replace('?', '')

print(df)

df.to_excel('data_procesada.xlsx', index=False, engine='openpyxl')
